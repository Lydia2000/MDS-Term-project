# %%
from data_helpers import fit_pca

feature = fit_pca()
train_datasets, validation_datasets, test_datasets, expected_RUL_datasets = feature.result_df()
train_datasets[0]
# Out:
#        Unit Number  Time (Cycles)      PCA1      PCA2      PCA3      PCA4  \
# 0                2              1 -4.888067 -0.073280 -0.191105  0.136955
# 1                2              2 -4.333902 -0.150475 -0.665323  1.892024
# 2                2              3 -5.003945  0.224774 -0.568979  1.958785
# 3                2              4 -5.107367  0.365191 -0.194350  1.811717
# 4                2              5 -5.464810  0.203329 -0.452717  1.338957
# ...            ...            ...       ...       ...       ...       ...
# 16109          100            196  6.962576 -0.877323  0.938418  0.648615
# 16110          100            197  7.102584 -0.945318  1.842089  0.656173
# 16111          100            198  8.083038 -0.690145 -0.041760  0.281251
# 16112          100            199  7.826214 -0.745422 -0.291177 -0.851751
# 16113          100            200  7.925748 -1.268775  2.339487  0.179086
#
#            PCA5      PCA6      PCA7      PCA8      PCA9     PCA10
# ...

# %%
validation_datasets[0]
# Out:
#       Unit Number  Time (Cycles)      PCA1      PCA2      PCA3      PCA4  \
# 0               1              1 -2.708793 -0.482522  1.180459  0.510939
# 1               1              2 -2.124134 -0.827167  0.130960  1.165523
# 2               1              3 -2.734900 -0.607813  0.563753 -2.122523
# 3               1              4 -3.134584 -0.889775 -0.262956  0.120436
# 4               1              5 -2.192166 -0.417691  1.026407 -0.295209
# ...           ...            ...       ...       ...       ...       ...
# 4512           92            337  6.272256  3.336349 -0.849942  0.907094
# 4513           92            338  7.278000  3.512381 -0.373529 -1.433674
# 4514           92            339  7.393815  3.582849  0.075628 -1.422593
# 4515           92            340  7.633117  3.386969 -1.741670 -0.459706
# 4516           92            341  8.159130  3.981281  1.009718  0.890971
#
#           PCA5      PCA6      PCA7      PCA8      PCA9     PCA10
# ...

# %%
def Calculate_RUL(df):
    max_cycles = df.groupby('Unit Number')['Time (Cycles)'].max()
    merged = df.merge(max_cycles.to_frame(name='max_time_cycle'), left_on='Unit Number',right_index=True)
    merged["RUL"] = merged["max_time_cycle"] - merged['Time (Cycles)']
    merged = merged.drop("max_time_cycle", axis=1)
    return merged

# %%
for i in range(4):
    train_datasets[i] = Calculate_RUL(train_datasets[i])

# %%
train_datasets[0]
# Out:
#        Unit Number  Time (Cycles)      PCA1      PCA2      PCA3      PCA4  \
# 0                2              1 -4.888067 -0.073280 -0.191105  0.136955
# 1                2              2 -4.333902 -0.150475 -0.665323  1.892024
# 2                2              3 -5.003945  0.224774 -0.568979  1.958785
# 3                2              4 -5.107367  0.365191 -0.194350  1.811717
# 4                2              5 -5.464810  0.203329 -0.452717  1.338957
# ...            ...            ...       ...       ...       ...       ...
# 16109          100            196  6.962576 -0.877323  0.938418  0.648615
# 16110          100            197  7.102584 -0.945318  1.842089  0.656173
# 16111          100            198  8.083038 -0.690145 -0.041760  0.281251
# 16112          100            199  7.826214 -0.745422 -0.291177 -0.851751
# 16113          100            200  7.925748 -1.268775  2.339487  0.179086
#
#            PCA5      PCA6      PCA7      PCA8      PCA9     PCA10  RUL
# ...

# %%
test_datasets[0]
# Out:
#        Unit Number  Time (Cycles)      PCA1      PCA2      PCA3      PCA4  \
# 0                1              1 -2.231481 -0.837578 -1.483258  0.039321
# 1                1              2 -3.315484 -0.099819  1.534633 -0.376132
# 2                1              3 -2.099436 -0.435696 -0.381512 -0.203652
# 3                1              4 -2.606579 -0.868152 -1.345495  1.297065
# 4                1              5 -3.238460 -0.813277 -0.472825  0.366541
# ...            ...            ...       ...       ...       ...       ...
# 13091          100            194  2.301264  5.269805 -1.612978  1.513925
# 13092          100            195  2.525270  4.784544  0.499591 -0.243667
# 13093          100            196  2.248461  5.128793  0.830487  0.338644
# 13094          100            197  2.413122  5.337485  0.829177 -1.560932
# 13095          100            198  3.664534  5.495442 -1.237517 -0.286210
#
#            PCA5      PCA6      PCA7      PCA8      PCA9     PCA10
# ...

# %%
from data_helpers import fit_ElasticNet

feature = fit_ElasticNet()
train_datasets, validation_datasets, test_datasets, expected_RUL_datasets = feature.result_df()
train_datasets[0]
# Out:
#        Unit Number  Time (Cycles)       S11        S9        S4       S12  \
# 0                1              1 -0.295941 -0.873456 -0.956197  0.363967
# 1                1              2 -0.220789 -0.972064 -0.673151  1.207475
# 2                1              3 -1.047460 -0.559491 -0.555029  1.397945
# 3                1              4 -1.573524 -0.720427 -0.814674  1.996563
# 4                1              5 -1.009884 -0.456697 -0.329929  1.085030
# ...            ...            ...       ...       ...       ...       ...
# 16598           98            152  2.409529  0.001924  2.369037 -1.323049
# 16599           98            153  2.559832 -0.295296  1.660307 -2.125742
# 16600           98            154  2.071345 -0.279016  2.207455 -2.057717
# 16601           98            155  2.559832 -0.425068  1.757256 -2.656336
# 16602           98            156  2.785288 -0.299017  2.560706 -2.506681
#
#              S7       S14       S21       S15       S20        S2
# ...

# %%
for i in range(4):
    train_datasets[i] = Calculate_RUL(train_datasets[i])

# %%
train_datasets[0]
# Out:
#        Unit Number  Time (Cycles)       S11        S9        S4       S12  \
# 0                1              1 -0.295941 -0.873456 -0.956197  0.363967
# 1                1              2 -0.220789 -0.972064 -0.673151  1.207475
# 2                1              3 -1.047460 -0.559491 -0.555029  1.397945
# 3                1              4 -1.573524 -0.720427 -0.814674  1.996563
# 4                1              5 -1.009884 -0.456697 -0.329929  1.085030
# ...            ...            ...       ...       ...       ...       ...
# 16598           98            152  2.409529  0.001924  2.369037 -1.323049
# 16599           98            153  2.559832 -0.295296  1.660307 -2.125742
# 16600           98            154  2.071345 -0.279016  2.207455 -2.057717
# 16601           98            155  2.559832 -0.425068  1.757256 -2.656336
# 16602           98            156  2.785288 -0.299017  2.560706 -2.506681
#
#              S7       S14       S21       S15       S20        S2  RUL
# ...

# %%
validation_datasets[0]
# Out:
#       Unit Number  Time (Cycles)       S11        S9        S4       S12  \
# 0              21              1 -0.260058 -0.779786  0.303610  0.350607
# 1              21              2 -0.967109 -0.925428 -0.373517 -0.148353
# 2              21              3 -0.297271 -0.742347  0.106668 -0.323663
# 3              21              4 -0.594977 -0.584362  0.169734  0.418033
# 4              21              5  0.223713 -0.777317 -0.714293  0.431519
# ...           ...            ...       ...       ...       ...       ...
# 4023          100            196  2.084374 -0.035117  2.291841 -2.710575
# 4024          100            197  1.972735 -0.051986  2.839517 -2.454353
# 4025          100            198  2.158801 -0.019484  2.242052 -2.009335
# 4026          100            199  3.275197  0.302246  2.059493 -2.467838
# 4027          100            200  2.568146 -0.201331  2.680193 -2.966797
#
#             S7       S14       S21       S15       S20        S2
# ...
